# %%
import pandas as pd

# %%
gestures = pd.read_csv('gestures.csv')
gestures
# Out:
#      gesture_num       1_x       1_y       2_x       2_y       3_x       3_y  \
# 0              1  0.567529  0.649895  0.513559  0.674526  0.475070  0.719334
# 1              1  0.561608  0.659064  0.507816  0.682847  0.469020  0.725074
# 2              1  0.561168  0.663301  0.507199  0.689664  0.467073  0.731581
# 3              1  0.562807  0.659700  0.508492  0.690664  0.468254  0.734919
# 4              1  0.563019  0.662489  0.509320  0.691888  0.469848  0.735576
# ..           ...       ...       ...       ...       ...       ...       ...
# 204            1  0.580731  0.634271  0.518512  0.659777  0.470872  0.692124
# 205            1  0.579092  0.630298  0.517599  0.654808  0.469565  0.687955
# 206            1  0.576509  0.634734  0.514109  0.658878  0.466279  0.689772
# 207            1  0.577053  0.634647  0.516839  0.656775  0.468821  0.686193
# 208            1  0.577914  0.637303  0.517527  0.657798  0.471070  0.684765
#
# ...

# %%
gestures['1_x']
# Out:
# 0      0.567529
# 1      0.561608
# 2      0.561168
# 3      0.562807
# 4      0.563019
#          ...
# 204    0.580731
# 205    0.579092
# 206    0.576509
# 207    0.577053
# 208    0.577914
# Name: 1_x, Length: 209, dtype: float64

# %%
gestures[['11_x', '12_x', '13_x', '14_x', '15_x']].plot()
